# %%
#organising the list datatype

# %%
cars = ['kia','audi','maruti','hyundai','volkswagan','benz','suzuki','bmw']

# %%
print(cars)
# Out:
# ['kia', 'audi', 'maruti', 'hyundai', 'volkswagan', 'benz', 'suzuki', 'bmw']

# %%
# want to organize the list in alphabatical order

# %%
print(sorted(cars))
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'maruti', 'suzuki', 'volkswagan']

# %%
cars.sort()

# %%
print(cars)
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'maruti', 'suzuki', 'volkswagan']

# %% [raw]
# # how many cars there in the list

# %%
len(cars)
# Out:
# 8

# %%
# want to get the opposite order of the list (z-a)

# %%
cars.reverse()

# %%
print(cars)
# Out:
# ['volkswagan', 'suzuki', 'maruti', 'kia', 'hyundai', 'bmw', 'benz', 'audi']

# %%
# General syntax of slicing

# %%
# [start_value:stop_value:step_count]

# %%
students = ['divya','harika','naveen','hafsa','karthika','vicky']

# %%
print(students)
# Out:
# ['divya', 'harika', 'naveen', 'hafsa', 'karthika', 'vicky']

# %%
print(students[0:1])
# Out:
# ['divya']

# %%
print(students[0:2])
# Out:
# ['divya', 'harika']

# %%
print(students[2:4])
# Out:
# ['naveen', 'hafsa']

# %%
print(students[0:6:2])
# Out:
# ['divya', 'naveen', 'karthika']

# %%
print(students[3:6])
# Out:
# ['hafsa', 'karthika', 'vicky']

# %%
print(students)
# Out:
# ['divya', 'harika', 'naveen', 'hafsa', 'karthika', 'vicky']

# %%
# introduction to tuple datatype

# %%
area_size = (27,30)

# %%
print(area_size)
# Out:
# (27, 30)

# %%
type(area_size)
# Out:
# tuple

# %%
area_size[0] = 28
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 area_size[0] = 28
#
# TypeError: 'tuple' object does not support item assignment
