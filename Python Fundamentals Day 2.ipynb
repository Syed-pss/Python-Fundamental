# %%
a=2
b=3
c=a+b

# %%
print(c)
# Out:
# 5

# %%
first name = 'Farhat'

# %%
print(first name)
# Out:
#   Cell In[6], line 1
#     print(first name)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
first name ='farhat'
# Out:
#   Cell In[7], line 1
#     first name ='farhat'
#           ^
# SyntaxError: invalid syntax

# %%
first_name = 'farhat'

# %%
print(first_name)
# Out:
# farhat

# %%
1name = 'anand'
# Out:
#   Cell In[10], line 1
#     1name = 'anand'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = 'anand'

# %%
print(name1)
# Out:
# anand

# %%
name@ = 'vachana'
# Out:
#   Cell In[13], line 1
#     name@ = 'vachana'
#           ^
# SyntaxError: invalid syntax

# %%
name = 'akash'

# %%
print(name)
# Out:
# akash

# %%
name2 = "Hajera"

# %%
print(name2)
# Out:
# Hajera

# %%
fullname = 'syed farhat ali'

# %%
print(fullname)
# Out:
# syed farhat ali

# %%
print(fullname.title())
# Out:
# Syed Farhat Ali

# %%
print(fullname.upper())
# Out:
# SYED FARHAT ALI

# %%
print(fullname.lower())
# Out:
# syed farhat ali
