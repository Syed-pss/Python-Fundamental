# %%
# Dictionary is a combination of key value pairs
# Classification : It is classified as a mutable datatype

# %%
alien = {'color':'green','points': 5}
print (alien)
# Out:
# {'color': 'green', 'points': 5}

# %%
# To verify & validate waht datatype it is 
type(alien)
# Out:
# dict

# %%
# dictionary in the shortform it is written as dict....
# How to add new key value pairs in the dictionary
# want to add start_position:level1

# %%
alien['start_position'] = 'level1'
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level1'}

# %%
# Note : In the dictionaries keys will be acting as indexing points...!

# %%
alien['color']
# Out:
# 'green'

# %%
alien['start_position']
# Out:
# 'level1'

# %%
alien['points']
# Out:
# 5

# %%
# Give the key and get the value...!
# Create a new user account in instagram...!

# %%
user_account = {'username':'codetraining01','username':'code','dob':'01-01-2020','password':'123456'}
print(user_account)
# Out:
# {'username': 'code', 'dob': '01-01-2020', 'password': '123456'}

# %%
# want to delete a key value pair...
# want to delete a username...!

# %%
del(user_account)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 del(user_account)
#
# NameError: name 'user_account' is not defined

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level1'}

# %%
alien['level1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 alien['level1']
#
# KeyError: 'level1'

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level1'}

# %%
for k,v in alien.items():
    print(k)
    print(v)
# Out:
# color
# green
# points
# 5
# start_position
# level1

# %%
for k,v in aline.items():
    print(f"key:{k}")
    print(f"value:{v}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 for k,v in aline.items():
#       2     print(f"key:{k}")
#       3     print(f"value:{v}")
#
# NameError: name 'aline' is not defined

# %%
for k,v in alien.items():
    print(f"key:{k}")
    print(f"value:{v}\n")
# Out:
# key:color
# value:green
#
# key:points
# value:5
#
# key:start_position
# value:level1
