# %%
dimension = (20,60)
print(dimension)
# Out:
# (20, 60)

# %%
# General syntax for loop

# %%
students = ['vicky','sudhakar','navya','neha','sai','david']
print(students)
# Out:
# ['vicky', 'sudhakar', 'navya', 'neha', 'sai', 'david']

# %%
message = f"keep up the good work,{students[0].title()}"
print(message)
# Out:
# keep up the good work,Vicky

# %%
for x in students:
    print(f"keep up the good work,{x.title()}")
# Out:
# keep up the good work,Vicky
# keep up the good work,Sudhakar
# keep up the good work,Navya
# keep up the good work,Neha
# keep up the good work,Sai
# keep up the good work,David

# %%
for x in students:
    print(f"keep up the good work,{x.title()}")
    print(f"i will be looking forword to receive your github url for the review,{x.title()}")
# Out:
# keep up the good work,Vicky
# i will be looking forword to receive your github url for the review,Vicky
# keep up the good work,Sudhakar
# i will be looking forword to receive your github url for the review,Sudhakar
# keep up the good work,Navya
# i will be looking forword to receive your github url for the review,Navya
# keep up the good work,Neha
# i will be looking forword to receive your github url for the review,Neha
# keep up the good work,Sai
# i will be looking forword to receive your github url for the review,Sai
# keep up the good work,David
# i will be looking forword to receive your github url for the review,David

# %%
for x in students:
    print(f"keep up the good work,{x.title()}")
    print(f"i will be looking forword to receive your github url for the review,{x.title()}.\n")
# Out:
# keep up the good work,Vicky
# i will be looking forword to receive your github url for the review,Vicky.
#
# keep up the good work,Sudhakar
# i will be looking forword to receive your github url for the review,Sudhakar.
#
# keep up the good work,Navya
# i will be looking forword to receive your github url for the review,Navya.
#
# keep up the good work,Neha
# i will be looking forword to receive your github url for the review,Neha.
#
# keep up the good work,Sai
# i will be looking forword to receive your github url for the review,Sai.
#
# keep up the good work,David
# i will be looking forword to receive your github url for the review,David.

# %%
print(students)
# Out:
# ['vicky', 'sudhakar', 'navya', 'neha', 'sai', 'david']

# %%
for x in students:
print(f"keep up the good work,{x.title()}")
# Out:
#   Cell In[23], line 2
#     print(f"keep up the good work,{x.title()}")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
for x in students:
    print(f"keep up the good work,{x.title()}")
    print(f"i will be looking forword to receive your github url for the review,{x.title()}.\n")
    print("thank you all for joining in the python session")
# Out:
# keep up the good work,Vicky
# i will be looking forword to receive your github url for the review,Vicky.
#
# thank you all for joining in the python session
# keep up the good work,Sudhakar
# i will be looking forword to receive your github url for the review,Sudhakar.
#
# thank you all for joining in the python session
# keep up the good work,Navya
# i will be looking forword to receive your github url for the review,Navya.
#
# thank you all for joining in the python session
# keep up the good work,Neha
# i will be looking forword to receive your github url for the review,Neha.
#
# thank you all for joining in the python session
# keep up the good work,Sai
# i will be looking forword to receive your github url for the review,Sai.
#
# thank you all for joining in the python session
# keep up the good work,David
# i will be looking forword to receive your github url for the review,David.
#
# thank you all for joining in the python session
